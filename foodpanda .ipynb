# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
os.getcwd()
# Out:
# '/Users/ryan/Downloads/01Foundation/13-web-scraping-beautifulsoup'

# %%
df = pd.read_csv('fp_df_final.csv')

# %%
df.rename(columns = {'Merge', 'keys'})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3f1e11d145f6> in <module>
# ----> 1 df.rename(columns = {'Merge', 'keys'})
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in rename(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    4294         4  3  6
#    4295         """
# -> 4296         return super().rename(
#    4297             mapper=mapper,
#    4298             index=index,
#
# ...

# %%
df.rating = df.rating.str.extract(r'(\d.+|\d)[\/]')

# %%
def clean(x):
    for 
    s.strip('[]')
    s.strip('\'')
# Out:
# 'Noodles'

# %%
df.cuisines_type

# %%
ctype = ["Chinese","Japanese","Western","Hong Kong","Malaysian","Taiwanese","Itallian","American","Indonesian","Drinks","Mexican","Salad","Korean","Fast Food","Middle Eastern","Dim Sum","Pizza","German","Vietnamese", "French","Pasta","Burger","Vegertarian","Thai"]
def cuisines(x):
    for i in ctype:
        if x in ctype:
            return 1
        else:
            return 0
df['c_type'] = df['cuisines_type'].apply(cuisines)

# %%
final.cuisine_type.value_counts().plot.pie(autopct = '%1.1f%%', ylabel=' ')
# Out:
# <AxesSubplot:ylabel=' '>

# %%
#price vs cuisines_type (to check any relationship between two aspects)
s = sns.boxplot(data = final, x = 'cuisine_type', y = 'avg_price')
s.set_xticklabels(s.get_xticklabels(), rotation=40, ha="right")
s.tight_layout()
s.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-399-087ad7a85da2> in <module>
#       2 s = sns.boxplot(data = final, x = 'cuisine_type', y = 'avg_price')
#       3 s.set_xticklabels(s.get_xticklabels(), rotation=40, ha="right")
# ----> 4 s.tight_layout()
#       5 s.show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'tight_layout'

# %%
# the ratio of cuisines type in fp
sns.countplot(x = 'cuisines_type1', data = final)
# Out:
# <AxesSubplot:xlabel='cuisines_type1', ylabel='count'>

# %%
print(final.promotion.value_counts())
# Out:
# 10% off $80            88
# 20% off $100           44
# 10% off $200            7
# 10% off $100            7
# 30% off $100            7
# 10% off $150            4
# 25% off $120            4
# 50% off                 4
# 20% off $150            4
# 15% off $80             3
# 20% off $200            3
# Free Delivery $250      2
# 35% off $100            2
# Free Delivery $200      2
# 20% off $80             1
# 15% off                 1
# 10% off $300            1
# 10% off $250            1
# 10% off $90             1
# Free 2 Cans of Coke     1
# 20% off                 1
# 10% off $120            1
# Name: promotion, dtype: int64

# %%
#How many % of resto doing promotion in fp in the sample
pro = final.promotion.value_counts()
pd.DataFrame(pro.head())
pro1 = sns.countplot(x = 'promotion', data = final)
pro1.set_xticklabels(pro1.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.show()

# %%
#do resto have provide free delivery fee always come with promotion?
sns.pairplot(final)

# %%
#how many resto rating are above average 3/5? does higher rating gain more comments?
sns.boxplot(data = final, x = 'rate_range',y='comment')
# Out:
# <AxesSubplot:xlabel='rate_range', ylabel='comment'>

# %%
def c_ctype(x):
    c_list = []
    for i in x.split(','):
        i.strip('"')
        c_list.append(i)
    return c_list
    
df['c_type'] = df.cuisines_type.apply(c_ctype)
df.c_type
# Out:
# 0      [['Noodles',  'Chinese',  'Limited Offers',  '...
# 1      [['Pasta',  'Pizza',  'Western',  'Salad',  'D...
# 2                   [['American',  'Pizza',  'Western']]
# 3          [['Italian',  'Pizza',  'Western',  'Pasta']]
# 4         [['Pasta',  'Western',  'Salad',  'Tea Time']]
#                              ...
# 578            [['Western',  'Pasta',  'Dine-in Price']]
# 579      [['Noodles',  'Chinese',  'Only on foodpanda']]
# 580                             [['European',  'Pasta']]
# 581                           [['Seafood',  'Japanese']]
# 582                             [['Sushi',  'Japanese']]
# Name: cuisines_type, Length: 583, dtype: object

# %%
df.cuisines_type[0]
# Out:
# "['Noodles', 'Chinese', 'Limited Offers', 'Dine-in Price', 'Carousel Deals']"

# %%
df
# Out:
#                                       Name rating  comment  \
# 0               shu family private kitchen    4.5    227.0
# 1                             small potato    3.8    131.0
# 2             pizza hut (tung lo wan road)    4.3    916.0
# 3                    phd (percival street)    4.1    114.0
# 4    express bar by lassana (causeway bay)    4.1      NaN
# ..                                     ...    ...      ...
# 578                           cafe du parc    4.5      NaN
# 579                           beef noodles    4.4    412.0
# 580                                soul 9+    3.5      7.0
# 581                             don moment    3.5      NaN
# 582                katsuisen (north point)    4.4    149.0
#
#               promotion                                      cuisines_type  \
# 0           10% off $80  ['Noodles', 'Chinese', 'Limited Offers', 'Dine...
# 1          30% off $100  ['Pasta', 'Pizza', 'Western', 'Salad', 'Dine-i...
# ...

# %%
c_type=pd.read_csv('c_type.csv')

# %%
final = pd.merge(df, c_type, on='keys')

# %%
final = final.drop(columns = "cuisines_type")

# %%
final
# Out:
#                                                   Name  rating  comment  \
# 0                           shu family private kitchen     4.5    227.0
# 1                                         small potato     3.8    131.0
# 2                         pizza hut (tung lo wan road)     4.3    916.0
# 3                                phd (percival street)     4.1    114.0
# 4                express bar by lassana (causeway bay)     4.1      NaN
# 5                               hot dog link (tin hau)     4.6    169.0
# 6                                 six garden restauant     4.1     56.0
# 7                                     the opera coffee     4.1      NaN
# 8                       din tai fung hk (causeway bay)     4.6   2721.0
# 9                                          simple viet     4.2     67.0
# 10                                   show boat gourmet     4.2      NaN
# 11                                     jacky's kitchen     4.2      NaN
# ...

# %%
final.cuisines_type1.value_counts()
# Out:
# ['Noodles']             93
# ['Hong Kong']           82
# ['Chinese']             78
# ['Japanese']            75
# ['Western']             61
# ['Drinks']              45
# ['American']            37
# ['Dessert']             25
# ['South East Asian']    25
# ['Pasta']               24
# ['Seafood']             20
# ['Indian']              13
# ['Korean']              11
# ['Taiwanese']           10
# ['Derrest']              6
# Name: cuisines_type1, dtype: int64

# %%
def cctype(x):
    if x == "['Mexican']":
        return "['American']"
    elif x == "['Middle Eastern']":
        return "['South East Asian']"
    elif x == "['Cakes & Bakery']":
        return "['Derrest']"   

    else:
        return x
final['cuisines_type1'] = final['cuisines_type1'].apply(cctype)

# %%
def type_c(x):
    if x == 
final['cuisines_type2'] =
# Out:
#   File "<ipython-input-114-88ac63887802>", line 1
#     final['cuisines_type2'] =
#                               ^
# SyntaxError: invalid syntax

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
final[final['cuisines_type1']=="['Hong Kong']"]
# Out:
#                                                 Name rating  comment  \
# 6                               six garden restauant    4.1     56.0
# 10                                 show boat gourmet    4.2      NaN
# 15                        hon lok roasted restaurant      4     23.0
# 17                                  first taste soup    4.4    108.0
# 39                       café de coral (king's road)    4.2    363.0
# 40                       café de coral (king's road)    4.2    363.0
# 41          café de coral (king's road) festive menu    4.5      2.0
# 42          café de coral (king's road) festive menu    4.5      2.0
# 45           ki’s roasted goose restaurant (tin hau)    4.4    473.0
# 47                                           nam bon    4.5    109.0
# 52                           chop chop (north point)    4.2    462.0
# 59                             wo shun kee (tin hau)      5      1.0
# 63                 ying lok restaurant (north point)      5      2.0
# ...

# %%
final.cuisines_type1[581] = "['Japanese']"
# Out:
# <ipython-input-180-10f11336b53e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final.cuisines_type1[581] = "['Japanese']"

# %%
def ctype(x):
    if x == "['Healthy']":
        return "['Western']"
    elif x == "['Vietnamese']":
        return "['South East Asian']"
    elif x == "['Dim Sum']":
        return "['Chinese']"   
    elif x == "['Sushi']":
        return "['Japanese']"
    elif x == "['Burger']":
        return "['American']"
    elif x == "['Pizza']":
        return "['American']"
    elif x == "['Fast Food']":
        return "['American']"
    elif x == "['Cake & Bakery']":
        return "['Dessert']"
    elif x == "['Sandwich']":
        return "['Western']"
    elif x == "['Italian']":
        return "['Western']"
    elif x == "['European']":
        return "['Western']"
    elif x == "['Beer & Wine']":
        return "['Drinks']"
    elif x == "['Vegetarian']":
        return "['Western']"
    elif x == "['Malaysian']":
        return "['South East Asian']"
    elif x == "['Singaporean']":
        return "['South East Asian']"
    elif x == "['Mediterranean']":
        return "['South East Asian']"
    elif x == "['Cantonese']":
        return "['Hong Kong']"
    elif x == "['German']":
        return "['Western']"
    elif x == "['Spanish']":
        return "['Western']"
    elif x == "['Indonesian']":
        return "['South East Asian']"
    elif x == "['Sichuan']":
        return "['Chinese']"
    elif x == "['French']":
        return "['Western']"
    elif x == "['Thai']":
        return "['South East Asian']"
    elif x == "['International']":
        return "['Western']"
    else:
        return x
final['cuisines_type1'] = final['cuisines_type1'].apply(ctype)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(color_codes=True) #overide maplot libs ugly colours.
mpl.rcParams['figure.figsize'] = [13, 8] #default figure size

sns.boxplot(data = final, x = 'cuisine_type',y='avg_price')
# Out:
# <AxesSubplot:xlabel='cuisine_type', ylabel='avg_price'>

# %%
final['rating'] = final['rating'].astype(float)
def rate_range(x):
    if x < 2:
        return "Low_rate"
    elif x > 2 and x <=4:
        return "Medium_rate"
    else:
        return "High_rate"

final["rate_range"] = final["rating"].apply(rate_range)

# %%
final.shape
# Out:
# (593, 11)

# %%
sns.boxplot(data = final, x = 'rate_range',y='comment')
# Out:
# <AxesSubplot:xlabel='rate_range', ylabel='comment'>

# %%
final.head()
# Out:
#                                     Name  rating  comment           promotion  \
# 0             shu family private kitchen     4.5    227.0         10% off $80
# 1                           small potato     3.8    131.0        30% off $100
# 2           pizza hut (tung lo wan road)     4.3    916.0                 NaN
# 3                  phd (percival street)     4.1    114.0  Free Delivery $200
# 4  express bar by lassana (causeway bay)     4.1      NaN                 NaN
#
#    avg_price  Exclusivity                       Merge         Delivery_Fee  \
# 0      102.0            0  shu family private kitchen  HK$ 12 delivery fee
# 1       52.0            0                small potato  HK$ 20 delivery fee
# 2      113.0            0                   pizza hut  HK$ 20 delivery fee
# 3       96.0            0                         phd        Free delivery
# 4       55.0            0      express bar by lassana   HK$ 2 delivery fee
#
#    cuisine_type   rate_range
# ...

# %%
final = final.rename(columns = {'cuisines_type1':'cuisine_type'})

# %%
cols = final.columns.tolist()

# %%
cols
# Out:
# ['Name',
#  'rating',
#  'comment',
#  'promotion',
#  'avg_price',
#  'Exclusivity',
#  'Merge',
#  'Delivery_Fee',
#  'cuisine_type',
#  'rate_range']

# %%
cols = cols[4:]+cols[:4]

# %%
cols = ['Merge','Name','cuisine_type','rating', 'rate_range',
 'comment',
 'promotion',
 'avg_price',
 'Exclusivity',
 'Delivery_Fee',]

# %%
final = final[cols]

# %%
final.head()
# Out:
#                         Merge                                   Name  \
# 0  shu family private kitchen             shu family private kitchen
# 1                small potato                           small potato
# 2                   pizza hut           pizza hut (tung lo wan road)
# 3                         phd                  phd (percival street)
# 4      express bar by lassana  express bar by lassana (causeway bay)
#
#    cuisine_type  rating   rate_range  comment           promotion  avg_price  \
# 0   ['Noodles']     4.5    High_rate    227.0         10% off $80      102.0
# 1     ['Pasta']     3.8  Medium_rate    131.0        30% off $100       52.0
# 2  ['American']     4.3    High_rate    916.0                 NaN      113.0
# 3   ['Western']     4.1    High_rate    114.0  Free Delivery $200       96.0
# 4     ['Pasta']     4.1    High_rate      NaN                 NaN       55.0
#
#    Exclusivity  Delivery_Fee
# 0            0            12
# ...

# %%
final.describe()
# Out:
#            rating      comment   avg_price  Exclusivity  Delivery_Fee
# count  593.000000   542.000000  593.000000   593.000000    593.000000
# mean     4.250927   218.027675   80.635750     0.229342     18.202361
# std      0.442738   404.688398   65.826134     0.420765     11.314135
# min      1.000000     1.000000   13.000000     0.000000      0.000000
# 25%      4.100000    22.000000   43.000000     0.000000     17.000000
# 50%      4.300000    83.500000   65.000000     0.000000     20.000000
# 75%      4.500000   230.000000   97.000000     0.000000     20.000000
# max      5.000000  3666.000000  738.000000     1.000000    270.000000

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 593 entries, 0 to 604
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Merge         593 non-null    object
#  1   Name          593 non-null    object
#  2   cuisine_type  593 non-null    object
#  3   rating        593 non-null    float64
#  4   rate_range    593 non-null    object
#  5   comment       542 non-null    float64
#  6   promotion     189 non-null    object
#  7   avg_price     593 non-null    float64
#  8   Exclusivity   593 non-null    int64
#  9   Delivery_Fee  593 non-null    object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 71.0+ KB

# %%
final.Delivery_Fee = pd.to_numeric(final.Delivery_Fee)

# %%
sns.countplot(final.Exclusivity, )
# Out:
# /Users/ryan/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Exclusivity', ylabel='count'>

# %%
sns.countplot(final.Delivery_Fee)
# Out:
# /Users/ryan/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Delivery_Fee', ylabel='count'>

# %%
final[final['cuisine_type']=="['Chinese']"].max()
# Out:
# Merge           young boss yummy food
# Name            young boss yummy food
# cuisine_type              ['Chinese']
# rating                              5
# rate_range                Medium_rate
# comment                          2962
# avg_price                         738
# Exclusivity                         1
# Delivery_Fee                       25
# dtype: object

# %%
final.Exclusivity.value_counts()
# Out:
# 0    457
# 1    136
# Name: Exclusivity, dtype: int64

# %%
import pandas as pd
s = pd.read_csv('TinHau_fp.csv')
v = pd.read_csv('deliveryfee.csv')

# %%
s=s.drop(columns = 'new')

# %%
s
# Out:
#                                       Name rating  comment  \
# 0               shu family private kitchen  4.5/5    227.0
# 1                             small potato  3.8/5    131.0
# 2             pizza hut (tung lo wan road)  4.3/5    916.0
# 3                    phd (percival street)  4.1/5    114.0
# 4    express bar by lassana (causeway bay)  4.1/5      NaN
# ..                                     ...    ...      ...
# 584                           cafe du parc  4.5/5      NaN
# 585                           beef noodles  4.4/5    412.0
# 586                                soul 9+  3.5/5      7.0
# 587                             don moment  3.5/5      NaN
# 588                katsuisen (north point)  4.4/5    149.0
#
#               promotion                                      cuisines_type  \
# 0           10% off $80  ['Noodles', 'Chinese', 'Limited Offers', 'Dine...
# 1          30% off $100  ['Pasta', 'Pizza', 'Western', 'Salad', 'Dine-i...
# ...

# %%
v['Name'] = v['Name'].str.lower()

# %%
v
# Out:
#                                         Name         Delivery_Fee
# 0    ming ming cart noodle bar (north point)  HK$ 17 delivery fee
# 1                 shu family private kitchen  HK$ 12 delivery fee
# 2                               small potato  HK$ 20 delivery fee
# 3               pizza hut (tung lo wan road)  HK$ 20 delivery fee
# 4                      phd (percival street)        Free delivery
# ..                                       ...                  ...
# 587                   mr.tree (causeway bay)  HK$ 20 delivery fee
# 588                            rb restaurant  HK$ 20 delivery fee
# 589                           sushi yorokobu  HK$ 20 delivery fee
# 590                mini melts (causeway bay)  HK$ 25 delivery fee
# 591                             cafe du parc  HK$ 17 delivery fee
#
# [592 rows x 2 columns]

# %%
h = pd.merge(s, v, on='Name')

# %%
h.drop(columns = 'new').head()
# Out:
#                                     Name rating  comment           promotion  \
# 0             shu family private kitchen  4.5/5    227.0         10% off $80
# 1                           small potato  3.8/5    131.0        30% off $100
# 2           pizza hut (tung lo wan road)  4.3/5    916.0                 NaN
# 3                  phd (percival street)  4.1/5    114.0  Free Delivery $200
# 4  express bar by lassana (causeway bay)  4.1/5      NaN                 NaN
#
#                                        cuisines_type   avg_price  \
# 0  ['Noodles', 'Chinese', 'Limited Offers', 'Dine...  102.444000
# 1  ['Pasta', 'Pizza', 'Western', 'Salad', 'Dine-i...   51.870000
# 2                   ['American', 'Pizza', 'Western']  113.022222
# 3           ['Italian', 'Pizza', 'Western', 'Pasta']   95.687500
# 4          ['Pasta', 'Western', 'Salad', 'Tea Time']   54.586207
#
#           Delivery_Fee
# 0  HK$ 12 delivery fee
# 1  HK$ 20 delivery fee
# 2  HK$ 20 delivery fee
# ...

# %%
h
# Out:
#                                       Name rating  comment  \
# 0               shu family private kitchen  4.5/5    227.0
# 1                             small potato  3.8/5    131.0
# 2             pizza hut (tung lo wan road)  4.3/5    916.0
# 3                    phd (percival street)  4.1/5    114.0
# 4    express bar by lassana (causeway bay)  4.1/5      NaN
# ..                                     ...    ...      ...
# 578                           cafe du parc  4.5/5      NaN
# 579                           beef noodles  4.4/5    412.0
# 580                                soul 9+  3.5/5      7.0
# 581                             don moment  3.5/5      NaN
# 582                katsuisen (north point)  4.4/5    149.0
#
#               promotion                                      cuisines_type  \
# 0           10% off $80  ['Noodles', 'Chinese', 'Limited Offers', 'Dine...
# 1          30% off $100  ['Pasta', 'Pizza', 'Western', 'Salad', 'Dine-i...
# ...
